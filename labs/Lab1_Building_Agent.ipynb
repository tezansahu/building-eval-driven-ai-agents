# %% [markdown]
# # Lab 1: Building AI Agents with Microsoft Agent Framework
#
# **Objective**: Build a fully-functional, multi-capability campus management AI agent from scratch.
#
# ## What You'll Build
#
# A **Campus Management Agent** that can:
# - 📅 **Manage Events** — browse events, get details, register students, view participants
# - 🏛️ **Manage Venues** — list venues, check availability, book spaces for clubs
# - 📢 **Send Notifications** — notify event participants and the campus community
#
# ## What You'll Learn
#
# 1. How to design good tool functions (docstrings, type hints, return format)
# 2. How to use the Microsoft Agent Framework to create agents
# 3. How to craft effective system-prompt instructions
# 4. How to handle multi-turn conversations with threads
# 5. How to test your agent thoroughly
#
# ---

# %% [markdown]
# ## Part A: Setup

# %% [markdown]
# Install all required packages for this lab.

# %%
# Install all required packages
# !pip install -q agent-framework requests fastapi uvicorn pyngrok nest-asyncio

# %%
# Import required libraries
from google.colab import userdata
from agent_framework import Agent
from agent_framework.openai import OpenAIChatClient
from typing import Annotated, Optional
from pydantic import Field
import requests
import sys
sys.path.append('/content')  # For utils.py in Colab

print("✅ Libraries imported")

# %% [markdown]
# **Provide Notebook Access to the Secrets**
#
# - Look at the left sidebar of this Colab notebook
# - Click the 🔑 key icon (Secrets)
# - Toggle **"Notebook access"** to ON for both `GITHUB_PAT` and `NGROK_AUTHTOKEN` secrets

# %%
# Load GitHub PAT from Colab Secrets
GITHUB_PAT = userdata.get('GITHUB_PAT')
print(f"✅ GitHub PAT loaded ({len(GITHUB_PAT)} chars)")

# %% [markdown]
# ### Configure the Backend URL
#
# Paste the ngrok URL you obtained in **Lab 0** below.

# %%
# TODO: Paste your ngrok public URL from Lab 0 here
BACKEND_URL = ""  # e.g. "https://a1b2c3d4.ngrok-free.app"

if not BACKEND_URL:
    print("⚠️  WARNING: BACKEND_URL is not set! Please paste your ngrok URL from Lab 0.")
else:
    # Quick health-check to confirm the backend is reachable
    try:
        resp = requests.get(f"{BACKEND_URL}/")
        if resp.status_code == 200:
            print(f"✅ Backend reachable at: {BACKEND_URL}")
        else:
            print(f"⚠️  Backend returned status {resp.status_code}. Check your URL.")
    except Exception as e:
        print(f"❌ Could not reach backend: {e}")

# %% [markdown]
# ### Load Utility Functions

# %%
# Download utils.py helper functions
# !wget -q https://raw.githubusercontent.com/tezansahu/building-eval-driven-ai-agents/main/labs/utils.py -O utils.py

from utils import function_to_tool_schema, print_agent_response
print("✅ Utility functions loaded")

# %% [markdown]
# ---
# ## Part B: Explore the Mock Backend API
#
# Before building tools, let's understand what our backend offers.
#
# The mock backend has **three groups of endpoints**:
#
# | Group | Endpoint | Method | Description |
# |---|---|---|---|
# | **Events** | `/events` | GET | List all events |
# | | `/events/{id}` | GET | Get event details |
# | | `/events/{id}/register` | POST | Register a student |
# | | `/events/{id}/participants` | GET | List participants |
# | | `/events/{id}/register/{student_id}` | DELETE | Unregister a student |
# | **Venues** | `/venues` | GET | List all venues |
# | | `/venues/{id}` | GET | Get venue details |
# | | `/venues/{id}/availability` | GET | Check availability |
# | | `/venues/{id}/book` | POST | Book a venue |
# | **Notifications** | `/notifications/send` | POST | Send a notification |
# | | `/notifications/log` | GET | View sent notifications |
#
# > 💡 You can also explore the live API docs at `{BACKEND_URL}/docs` in your browser.
#
# Let's quickly browse the data available to understand what the agent will be working with:

# %%
# Browse all events available in the system
response = requests.get(f"{BACKEND_URL}/events")
events = response.json()
print(f"Found {len(events)} events:")
for e in events:
    print(f"  [{e['event_id']}] {e['name']}  |  {e['date']}  |  {e['venue']}")

# %%
# Browse all venues available in the system
response = requests.get(f"{BACKEND_URL}/venues")
venues = response.json()
print(f"Found {len(venues)} venues:")
for v in venues:
    print(f"  [{v['venue_id']}] {v['name']}  |  capacity: {v['capacity']}  |  {', '.join(v['facilities'])}")

# %% [markdown]
# ---
# ## Part C: Define Agent Tools — Event Management
#
# ### What Makes a Good Tool Function?
#
# An agent tool is just a Python function, but it needs to be written with care because **the LLM reads it**:
#
# | Element | Why It Matters |
# |---|---|
# | **Function name** | Must be descriptive — the LLM uses this to decide which tool to call |
# | **Docstring** | This is read directly by the LLM as the tool description; be specific about *when* to use it |
# | **Parameter annotations** (`Annotated[type, Field(description="...")]`) | Tells the LLM what data it needs to collect from the user |
# | **Return value** | A formatted string — the LLM uses it to craft the final response to the user |
# | **Error handling** | Wrap in `try/except` — agents should degrade gracefully, not crash |
#
# Let's build our tools one by one.

# %% [markdown]
# ### ✅ Tool 1: `get_events()` — Browse All Events (Pre-Implemented)

# %% [markdown]
# Study this complete implementation. Notice the structure:
# - The **docstring** explains exactly *when* the LLM should use this tool
# - The **return value** is a richly formatted string with emojis and structure
# - The **try/except** ensures graceful failure

# %%
def get_events() -> str:
    """
    Retrieve a list of all available campus events.

    Use this when users ask about upcoming events, what's happening on campus,
    or which events they could attend. Do NOT use this when the user already
    knows which specific event they are interested in.

    Returns a formatted list of events with names, dates, venues, and capacity info.
    """
    try:
        response = requests.get(f"{BACKEND_URL}/events")
        events = response.json()

        if not events:
            return "No events are currently available."

        result = f"Found {len(events)} upcoming campus events:\n\n"
        for event in events:
            spots_left = event['max_participants'] - len(event.get('participants', []))
            status = "🔴 FULL" if spots_left <= 0 else f"🟢 {spots_left} spots left"
            result += f"• **{event['name']}** (ID: `{event['event_id']}`)"
            result += f"  📅 {event['date']} at {event['time']}"
            result += f"  📍 {event['venue']}"
            result += f"  👥 {len(event.get('participants', []))}/{event['max_participants']} registered  {status}\n\n"

        return result.strip()
    except Exception as e:
        return f"Error fetching events: {str(e)}"

print("✅ Tool 1 defined: get_events()")

# %% [markdown]
# ### 📝 Tool 2: `get_event_details()` — Get Specific Event Info (Your Turn!)
#
# The user wants to know more about a *specific* event they have in mind.
# Implement the function below using the comments as your guide.

# %%
def get_event_details(
    event_id: Annotated[str, Field(description="The unique event identifier (e.g., 'ai_workshop', 'techfest2024')")]
) -> str:
    """
    Get detailed information about a specific campus event.

    Use this when a user asks about a particular event by name or ID — for example:
    - "Tell me more about the AI Workshop"
    - "What is TechFest 2024 about?"
    - "When does the Spring Hackathon start, and where?"

    Returns event description, schedule, venue, and registration availability.
    """
    # TODO: Implement this tool using the following steps:
    #
    # Step 1 — Make a GET request:
    #   URL: f"{BACKEND_URL}/events/{event_id}"
    #   Use: response = requests.get(...)
    #
    # Step 2 — Handle a missing event (status code 404):
    #   Return a helpful message such as:
    #   f"Event '{event_id}' not found. Try get_events() to see valid event IDs."
    #
    # Step 3 — Parse the successful JSON response (response.json()):
    #   Fields available: event['name'], event['event_id'], event['description'],
    #                    event['date'], event['time'], event['venue'],
    #                    event['max_participants'], event['participants'] (list of IDs)
    #
    # Step 4 — Build a formatted result string. Include:
    #   - Event name and ID
    #   - Description
    #   - Date and time
    #   - Venue
    #   - Capacity: how many are registered vs. max (e.g., "12/50 registered")
    #   - Whether spots are still available (or event is full)
    #
    # Step 5 — Wrap everything in try/except and return an error message on failure.

    pass  # ← Remove this and replace with your implementation

print("✅ Tool 2 defined: get_event_details()")

# %% [markdown]
# <details>
# <summary><b>💡 Solution</b></summary>
#
# ```python
# def get_event_details(
# 	event_id: Annotated[str, Field(description="The unique event identifier (e.g., 'ai_workshop', 'techfest2024')")]
# ) -> str:
# 	"""...(docstring as above)..."""
# 	try:
# 		response = requests.get(f"{BACKEND_URL}/events/{event_id}")
#
# 		if response.status_code == 404:
# 			return f"Event '{event_id}' not found. Try get_events() to see valid event IDs."
#
# 		event = response.json()
# 		registered = len(event.get('participants', []))
# 		capacity = event['max_participants']
# 		spots_left = capacity - registered
#
# 		result  = f"📋 **{event['name']}** (ID: `{event['event_id']}`)
#
# "
# 		result += f"📝 {event['description']}
#
# "
# 		result += f"📅 **Date:** {event['date']} at {event['time']}
# "
# 		result += f"📍 **Venue:** {event['venue']}
# "
# 		result += f"👥 **Capacity:** {registered}/{capacity} registered
# "
#
# 		if spots_left <= 0:
# 			result += "
# ⚠️  This event is **FULL** — no spots remaining."
# 		else:
# 			result += f"
# ✅ {spots_left} spot(s) still available — register now!"
#
# 		return result
# 	except Exception as e:
# 		return f"Error fetching event details: {str(e)}"
# ```
# </details>

# %% [markdown]
# ### 📝 Tool 3: `register_for_event()` — Sign Up a Student (Your Turn!)
#
# This is a **WRITE tool** — it changes data on the backend via a POST request.
# The agent must collect three pieces of information before calling this.

# %%
def register_for_event(
    student_id: Annotated[str, Field(description="The student's unique ID (e.g., 'S001')")],
    event_id: Annotated[str, Field(description="The event identifier to register for (e.g., 'ai_workshop')")],
    student_name: Annotated[str, Field(description="The full name of the student")]
) -> str:
    """
    Register a student for a specific campus event.

    Use this ONLY when a user explicitly asks to register or sign up for an event.
    Before calling this tool, make sure you have:
    - student_id   (ask the user if not provided)
    - event_id   (ask if unclear which event; use get_events() to clarify)
    - student_name (ask the user if not provided)

    Returns a confirmation message with event details, or an error if registration fails.
    """
    # TODO: Implement this WRITE tool using the following steps:
    #
    # Step 1 — Make a POST request:
    #   URL: f"{BACKEND_URL}/events/{event_id}/register"
    #   Body (JSON dict): {"student_id": student_id, "student_name": student_name}
    #   Use: response = requests.post(..., json={...})
    #
    # Step 2 — Parse the JSON response and check result.get("success"):
    #   If True:
    #    - Get event details: details = result.get("event_details", {})
    #    - Build a confirmation message that includes:
    #        student_name, event name (details.get('event_name')),
    #        date (details.get('date')), time (details.get('time')),
    #        venue (details.get('venue')), and participant count
    #   If False:
    #    - Return a failure message: result.get("message")
    #
    # Step 3 — Wrap in try/except and return an error string on failure.

    pass  # ← Remove this and replace with your implementation

print("✅ Tool 3 defined: register_for_event()")

# %% [markdown]
# <details>
# <summary><b>💡 Solution</b></summary>
#
# ```python
# def register_for_event(
# 	student_id: Annotated[str, Field(description="The student's unique ID (e.g., 'S001')")],
# 	event_id: Annotated[str, Field(description="The event identifier to register for (e.g., 'ai_workshop')")],
# 	student_name: Annotated[str, Field(description="The full name of the student")]
# ) -> str:
# 	"""...(docstring as above)..."""
# 	try:
# 		response = requests.post(
# 			f"{BACKEND_URL}/events/{event_id}/register",
# 			json={"student_id": student_id, "student_name": student_name}
# 		)
# 		result = response.json()
#
# 		if result.get("success"):
# 			details = result.get("event_details", {})
# 			msg  = f"✅ **{student_name}** is now registered!\n\n"
# 			msg += f"🎉 **{details.get('event_name', 'Event')}**\n"
# 			msg += f"📅 {details.get('date', 'TBD')} at {details.get('time', 'TBD')}\n"
# 			msg += f"📍 {details.get('venue', 'TBD')}\n"
# 			msg += f"👥 Total registered: {details.get('participants_count', '?')}"
# 			return msg
# 		else:
# 			return f"❌ Registration failed: {result.get('message')}"
# 	except Exception as e:
# 		return f"Error during registration: {str(e)}"
# ```
# </details>

# %% [markdown]
# ### 📝 Tool 4: `get_event_participants()` — View Who's Registered (Your Turn!)
#
# The user wants to know who has signed up for an event.

# %%
def get_event_participants(
    event_id: Annotated[str, Field(description="The event identifier (e.g., 'ai_workshop', 'techfest2024')")]
) -> str:
    """
    Get the list of students registered for a specific campus event.

    Use this when users ask about who is attending, how many people signed up,
    or want to see the participant/attendee list for an event.

    Returns total participant count and a numbered list of registered student IDs.
    """
    # TODO: Implement this tool using the following steps:
    #
    # Step 1 — Make a GET request:
    #   URL: f"{BACKEND_URL}/events/{event_id}/participants"
    #
    # Step 2 — Handle a missing event (status code 404):
    #   Return: f"Event '{event_id}' not found."
    #
    # Step 3 — Parse the JSON response:
    #   Fields: data.get('event_name'), data.get('participant_count', 0),
    #          data.get('participants', [])   ← list of student IDs
    #
    # Step 4 — Format the result:
    #   If participant_count == 0:
    #    Return a friendly "no one has registered yet" message
    #   Otherwise:
    #    Build a result string with:
    #      - Event name and total count as a header
    #      - A numbered list of student IDs (use enumerate starting at 1)
    #
    # Step 5 — Wrap in try/except.

    pass  # ← Remove this and replace with your implementation

print("✅ Tool 4 defined: get_event_participants()")

# %% [markdown]
# <details>
# <summary><b>💡 Solution</b></summary>
#
# ```python
# def get_event_participants(
# 	event_id: Annotated[str, Field(description="The event identifier")]
# ) -> str:
# 	"""...(docstring as above)..."""
# 	try:
# 		response = requests.get(f"{BACKEND_URL}/events/{event_id}/participants")
#
# 		if response.status_code == 404:
# 			return f"Event '{event_id}' not found."
#
# 		data = response.json()
# 		event_name = data.get('event_name', 'Event')
# 		count = data.get('participant_count', 0)
# 		participants = data.get('participants', [])
#
# 		if count == 0:
# 			return f"No one has registered for **{event_name}** yet. Be the first!"
#
# 		result  = f"📋 **{event_name}** — Registered Participants\n\n"
# 		result += f"Total: {count} student(s)\n\n"
# 		for i, student_id in enumerate(participants, 1):
# 			result += f"{i}. {student_id}\n"
#
# 		return result
# 	except Exception as e:
# 		return f"Error fetching participants: {str(e)}"
# ```
# </details>

# %% [markdown]
# ### ✅ Tool 5: `unregister_from_event()` — Cancel Registration (Pre-Implemented)
#
# This shows how to use the **DELETE** HTTP method — another common pattern for WRITE tools.

# %%
def unregister_from_event(
    student_id: Annotated[str, Field(description="The student's unique ID (e.g., 'S001')")],
    event_id: Annotated[str, Field(description="The event identifier to unregister from")]
) -> str:
    """
    Cancel a student's registration for a campus event.

    Use this when a user explicitly asks to cancel, unregister, or withdraw from an event.
    Requires the student_id and event_id — ask if either is missing.

    Returns a confirmation if successful, or an error message if not registered.
    """
    try:
        response = requests.delete(
            f"{BACKEND_URL}/events/{event_id}/register/{student_id}"
        )
        result = response.json()

        if result.get("success"):
            return f"✅ Student `{student_id}` has been unregistered from the event."
        else:
            return f"❌ Could not unregister: {result.get('message')}"
    except Exception as e:
        return f"Error during unregistration: {str(e)}"

print("✅ Tool 5 defined: unregister_from_event()")

# %% [markdown]
# ---
# ## Part D: Define Agent Tools — Venue Management
#
# Campus clubs need to book rooms and auditoriums. Let's add venue management capabilities to our agent.

# %% [markdown]
# ### ✅ Tool 6: `get_venues()` — List All Venues (Pre-Implemented)

# %%
def get_venues() -> str:
    """
    Retrieve a list of all campus venues with their facilities and capacity.

    Use this when users ask about available venues, where they can host an event,
    or what rooms/halls are available on campus.

    Returns a formatted list of venues with capacity and facilities.
    """
    try:
        response = requests.get(f"{BACKEND_URL}/venues")
        venues = response.json()

        if not venues:
            return "No venues found."

        result = f"Found {len(venues)} campus venues:\n\n"
        for venue in venues:
            result += f"• **{venue['name']}** (ID: `{venue['venue_id']}`)
"
            result += f"  👥 Capacity: {venue['capacity']}
"
            result += f"  🔧 Facilities: {', '.join(venue['facilities'])}\n\n"

        return result.strip()
    except Exception as e:
        return f"Error fetching venues: {str(e)}"

print("✅ Tool 6 defined: get_venues()")

# %% [markdown]
# ### 📝 Tool 7: `check_venue_availability()` — See If a Venue Is Free (Your Turn!)
#
# Before booking, always check if the venue is available on the desired date.

# %%
def check_venue_availability(
    venue_id: Annotated[str, Field(description="Venue identifier (e.g., 'seminar_a', 'lab_cs1', 'aud_main')")],
    date: Annotated[str, Field(description="Date to check in YYYY-MM-DD format (e.g., '2024-04-15')")],
    time_slot: Annotated[Optional[str], Field(description="Optional: specific time slot to check (e.g., '10:00-12:00'). If not provided, all bookings for that date are returned.")] = None
) -> str:
    """
    Check if a specific campus venue is available on a given date and optional time slot.

    Use this BEFORE booking a venue to confirm it is not already reserved.
    If the user specifies a time slot, check that specific slot; otherwise show all bookings for the date.

    Returns availability status and details of any existing bookings.
    """
    # TODO: Implement this tool using the following steps:
    #
    # Step 1 — Build the request URL with query parameters:
    #   Base URL: f"{BACKEND_URL}/venues/{venue_id}/availability?date={date}"
    #   If time_slot is provided (not None), append: f"&time_slot={time_slot}"
    #
    # Step 2 — Make a GET request to that URL
    #
    # Step 3 — Handle a 404 (venue not found):
    #   Return: f"Venue '{venue_id}' not found. Use get_venues() to see valid venue IDs."
    #
    # Step 4 — Parse the JSON response:
    #   Fields vary depending on whether time_slot was given:
    #
    #   With time_slot:
    #    data.get("venue_name"), data.get("date"), data.get("time_slot"),
    #    data.get("available")  ← True/False
    #    If available: return a "✅ available" message
    #    If not:
    #      data.get("existing_bookings", []) ← list of booking dicts
    #      Each booking has: "club_name", "purpose", "time_slot"
    #      Return a "❌ not available" message with who booked it
    #
    #   Without time_slot:
    #    data.get("venue_name"), data.get("date"),
    #    data.get("booked_slots", 0), data.get("available_slots", 8),
    #    data.get("bookings", [])  ← list of booking dicts for the day
    #    Return a summary of the day's bookings
    #
    # Step 5 — Wrap in try/except.

    pass  # ← Remove this and replace with your implementation

print("✅ Tool 7 defined: check_venue_availability()")

# %% [markdown]
# <details>
# <summary><b>💡 Solution</b></summary>
#
# ```python
# def check_venue_availability(
# 	venue_id: Annotated[str, Field(...)],
# 	date: Annotated[str, Field(...)],
# 	time_slot: Annotated[Optional[str], Field(...)] = None
# ) -> str:
# 	"""...(docstring as above)..."""
# 	try:
# 		url = f"{BACKEND_URL}/venues/{venue_id}/availability?date={date}"
# 		if time_slot:
# 			url += f"&time_slot={time_slot}"
#
# 		response = requests.get(url)
#
# 		if response.status_code == 404:
# 			return f"Venue '{venue_id}' not found. Use get_venues() to see valid venue IDs."
#
# 		data = response.json()
# 		venue_name = data.get("venue_name", venue_id)
#
# 		if time_slot:
# 			available = data.get("available", True)
# 			if available:
# 				return (
# 					f"✅ **{venue_name}** is available on {date} at {time_slot}. "
# 					f"Go ahead and book it!"
# 				)
# 			else:
# 				bookings = data.get("existing_bookings", [])
# 				msg = f"❌ **{venue_name}** is NOT available on {date} at {time_slot}.\n\n"
# 				msg += "Existing booking:\n"
# 				for b in bookings:
# 					msg += f"  • {b.get('club_name')} — {b.get('purpose')} ({b.get('time_slot')})\n"
# 				return msg
# 		else:
# 			booked = data.get("booked_slots", 0)
# 			total = data.get("available_slots", 8)
# 			bookings = data.get("bookings", [])
#
# 			msg = f"📋 **{venue_name}** on {date}:\n"
# 			msg += f"  {booked} slot(s) booked out of {total}\n\n"
# 			if bookings:
# 				msg += "Existing bookings:\n"
# 				for b in bookings:
# 					msg += f"  • {b.get('time_slot')} — {b.get('club_name')}: {b.get('purpose')}\n"
# 			else:
# 				msg += "No bookings yet — venue is fully available!"
# 			return msg
# 	except Exception as e:
# 		return f"Error checking venue availability: {str(e)}"
# ```
# </details>

# %% [markdown]
# ### 📝 Tool 8: `book_venue()` — Reserve a Venue (Your Turn!)
#
# This is a WRITE tool. Ensure you have all required fields before calling it.
# > **Important**: Always check availability before booking!

# %%
def book_venue(
    venue_id: Annotated[str, Field(description="Venue identifier (e.g., 'seminar_a', 'lab_cs1')")],
    club_name: Annotated[str, Field(description="Name of the club or organization booking the venue")],
    date: Annotated[str, Field(description="Booking date in YYYY-MM-DD format (e.g., '2024-04-15')")],
    time_slot: Annotated[str, Field(description="Time slot for the booking (e.g., '14:00-16:00')")],
    purpose: Annotated[str, Field(description="Purpose of the booking (e.g., 'Club annual meeting', 'AI Workshop')")],
    expected_attendees: Annotated[int, Field(description="Expected number of attendees (must not exceed venue capacity)")]
) -> str:
    """
    Book a campus venue for a club or organization.

    Use this when a user wants to reserve a venue for an event or meeting.
    Before calling this tool:
    1. Verify venue availability using check_venue_availability()
    2. Confirm all 6 fields are provided (ask if any are missing)
    3. Make sure expected_attendees does not exceed venue capacity

    Returns a booking confirmation with all details, or an error with the reason.
    """
    # TODO: Implement this WRITE tool using the following steps:
    #
    # Step 1 — Make a POST request:
    #   URL: f"{BACKEND_URL}/venues/{venue_id}/book"
    #   Body (JSON dict):
    #    {
    #      "club_name": club_name,
    #      "date": date,
    #      "time_slot": time_slot,
    #      "purpose": purpose,
    #      "expected_attendees": expected_attendees
    #    }
    #
    # Step 2 — Parse the JSON response and check result.get("success"):
    #   If True:
    #    - Get details: details = result.get("booking_details", {})
    #    - Build a confirmation message with:
    #        venue name (details.get('venue_name')), club name, date,
    #        time slot, purpose, and facilities (details.get('facilities', []))
    #   If False:
    #    - Return the failure message from result.get("message")
    #      (e.g., capacity exceeded, slot already taken)
    #
    # Step 3 — Wrap in try/except.

    pass  # ← Remove this and replace with your implementation

print("✅ Tool 8 defined: book_venue()")

# %% [markdown]
# <details>
# <summary><b>💡 Solution</b></summary>
#
# ```python
# def book_venue(
# 	venue_id: Annotated[str, Field(...)],
# 	club_name: Annotated[str, Field(...)],
# 	date: Annotated[str, Field(...)],
# 	time_slot: Annotated[str, Field(...)],
# 	purpose: Annotated[str, Field(...)],
# 	expected_attendees: Annotated[int, Field(...)]
# ) -> str:
# 	"""...(docstring as above)..."""
# 	try:
# 		response = requests.post(
# 			f"{BACKEND_URL}/venues/{venue_id}/book",
# 			json={
# 				"club_name": club_name,
# 				"date": date,
# 				"time_slot": time_slot,
# 				"purpose": purpose,
# 				"expected_attendees": expected_attendees
# 			}
# 		)
# 		result = response.json()
#
# 		if result.get("success"):
# 			details = result.get("booking_details", {})
# 			facilities = ", ".join(details.get("facilities", []))
# 			msg  = f"✅ **Venue booked successfully!**\n\n"
# 			msg += f"🏛️ **{details.get('venue_name')}**\n"
# 			msg += f"🎓 Booked by: {club_name}\n"
# 			msg += f"📅 Date: {date}\n"
# 			msg += f"⏰ Time slot: {time_slot}\n"
# 			msg += f"🎯 Purpose: {purpose}\n"
# 			msg += f"🔧 Facilities available: {facilities}"
# 			return msg
# 		else:
# 			return f"❌ Booking failed: {result.get('message')}"
# 	except Exception as e:
# 		return f"Error booking venue: {str(e)}"
# ```
# </details>

# %% [markdown]
# ---
# ## Part E: Define Agent Tools — Notifications
#
# The final capability: sending announcements to event participants or the campus community.

# %% [markdown]
# ### 📝 Tool 9: `send_event_notification()` — Send an Announcement (Your Turn!)
#
# This lets the agent inform registered students about updates, reminders, or changes.

# %%
def send_event_notification(
    event_id: Annotated[str, Field(description="Event ID for which to send the notification (e.g., 'ai_workshop')")],
    message: Annotated[str, Field(description="The notification message to be sent to recipients")],
    recipient_type: Annotated[str, Field(
        description="Who to notify: 'all_participants' (everyone registered for the event), "
                    "'all_students' (campus-wide broadcast), "
                    "or 'specific_students' (targeted to specific student IDs)"
    )]
) -> str:
    """
    Send a notification to event participants or the broader campus community.

    Use this when the user wants to:
    - Remind participants about an upcoming event
    - Share updates or changes about an event
    - Broadcast an announcement campus-wide

    Choose recipient_type based on scope:
    - 'all_participants'  → only students registered for the event
    - 'all_students'      → entire campus community
    - 'specific_students' → ask for student IDs (not covered by this tool variant)

    Returns confirmation of how many people were notified.
    """
    # TODO: Implement this WRITE tool using the following steps:
    #
    # Step 1 — Make a POST request:
    #   URL: f"{BACKEND_URL}/notifications/send"
    #   Body (JSON dict):
    #    {
    #      "event_id": event_id,
    #      "message": message,
    #      "recipient_type": recipient_type
    #    }
    #
    # Step 2 — Parse the JSON response and check result.get("success"):
    #   If True:
    #    - Get details: details = result.get("details", {})
    #    - Build a confirmation with:
    #        recipient count (details.get('recipient_count')),
    #        event_id, and sent_at timestamp (details.get('sent_at'))
    #   If False:
    #    - Return the failure message from result.get("message")
    #
    # Step 3 — Wrap in try/except.

    pass  # ← Remove this and replace with your implementation

print("✅ Tool 9 defined: send_event_notification()")

# %% [markdown]
# <details>
# <summary><b>💡 Solution</b></summary>
#
# ```python
# def send_event_notification(
# 	event_id: Annotated[str, Field(...)],
# 	message: Annotated[str, Field(...)],
# 	recipient_type: Annotated[str, Field(...)]
# ) -> str:
# 	"""...(docstring as above)..."""
# 	try:
# 		response = requests.post(
# 			f"{BACKEND_URL}/notifications/send",
# 			json={
# 				"event_id": event_id,
# 				"message": message,
# 				"recipient_type": recipient_type
# 			}
# 		)
# 		result = response.json()
#
# 		if result.get("success"):
# 			details = result.get("details", {})
# 			msg  = f"📢 **Notification sent successfully!**\n\n"
# 			msg += f"✉️ Message: \"{message}\"\n"
# 			msg += f"👥 Recipients: {details.get('recipient_count', '?')} student(s)\n"
# 			msg += f"🎯 Audience: {recipient_type.replace('_', ' ')}\n"
# 			msg += f"⏱️ Sent at: {details.get('sent_at', 'just now')}"
# 			return msg
# 		else:
# 			return f"❌ Notification failed: {result.get('message')}"
# 	except Exception as e:
# 		return f"Error sending notification: {str(e)}"
# ```
# </details>

# %% [markdown]
# ### ✅ Tool 10: `get_notification_history()` — View Sent Notifications (Pre-Implemented)

# %%
def get_notification_history() -> str:
    """
    Retrieve the history of all notifications sent through the system.

    Use this when users want to see what announcements have been sent,
    review past notifications, or confirm a notification was delivered.

    Returns a log of all sent notifications with timestamps and recipient info.
    """
    try:
        response = requests.get(f"{BACKEND_URL}/notifications/log")
        data = response.json()

        total = data.get("total_notifications", 0)
        notifications = data.get("notifications", [])

        if total == 0:
            return "No notifications have been sent yet."

        result = f"📋 **Notification History** ({total} sent)\n\n"
        for i, notif in enumerate(notifications, 1):
            result += f"**{i}. [{notif.get('timestamp', 'Unknown time')}]**\n"
            result += f"   📌 Event: {notif.get('event_id')}\n"
            result += f"   ✉️ Message: {notif.get('message')}\n"
            result += f"   👥 Sent to: {notif.get('recipient_count')} recipient(s) ({notif.get('recipient_type')})\n\n"

        return result.strip()
    except Exception as e:
        return f"Error fetching notification history: {str(e)}"

print("✅ Tool 10 defined: get_notification_history()")

# %% [markdown]
# ---
# ## Part F: Inspect Tool Schemas
#
# The Agent Framework automatically generates a **JSON Schema** from your function signatures.
# This schema is what the LLM actually "reads" to understand your tools.
#
# Let's verify that our functions produce correct, well-formed schemas.

# %%
import json
from utils import function_to_tool_schema

# Inspect schema for a zero-parameter tool
print("Schema for get_events() — no parameters:")
print(json.dumps(function_to_tool_schema(get_events), indent=2))

# %%
# Inspect schema for a multi-parameter WRITE tool
print("Schema for register_for_event() — three parameters:")
print(json.dumps(function_to_tool_schema(register_for_event), indent=2))

# %%
# Inspect schema for a tool with an optional parameter
print("Schema for check_venue_availability() — required + optional parameter:")
print(json.dumps(function_to_tool_schema(check_venue_availability), indent=2))

# %% [markdown]
# **What to check in your schemas:**
# - ✅ `"description"` field exists for each parameter (comes from `Field(description="...")`)
# - ✅ `"required"` list only includes mandatory parameters (optional ones with defaults are excluded)
# - ✅ Function docstring appears as the tool's top-level description
# - ✅ Parameter types are correctly mapped (str → string, int → integer)
#
# If any schema looks wrong, revisit the corresponding tool function and check your `Annotated[type, Field(description="...")]` annotations.

# %% [markdown]
# ---
# ## Part G: Craft the Agent Instructions
#
# The **system prompt (instructions)** is the most important part of your agent.
# It defines the agent's personality, capabilities, and decision-making rules.
#
# ### Anatomy of Great Agent Instructions
#
# ```
# 1. ROLE: Who is this agent? What domain does it own?
# 2. CAPABILITIES: What can it do? (Be specific — list tool categories)
# 3. BEHAVIORAL GUIDELINES: Tone, conciseness, when to use tools vs. respond from memory
# 4. INFORMATION-GATHERING RULES: When to ask for clarification vs. proceed
# 5. TOOL USAGE RULES: Sequencing (e.g., check availability before booking)
# 6. ERROR HANDLING: How to respond when tools fail
# 7. RESPONSE FORMAT: Level of detail, use of formatting, what to always include
# ```
#
# ### What makes instructions bad?
# - ❌ "Be helpful" — too vague, tells the LLM nothing
# - ❌ Missing tool usage rules — agent guesses instead of following a workflow
# - ❌ No guidance on missing info — agent either hallucinates values or gets stuck
# - ❌ No response format — inconsistent, unpredictable outputs
#
# ### Your Turn — Write the Instructions!

# %%
# TODO: Write comprehensive instructions for your campus management agent.
#
# Use the anatomy above as your guide. Here is a starter template — fill it in:
#
# Tips:
# - Be specific about which tools belong to which capability
# - Explicitly state the "check availability BEFORE booking" workflow
# - Define what info the agent must collect before calling WRITE tools
# - Specify tone (friendly, concise, professional, etc.)
# - Include a note about always echoing back specific details from tool results

AGENT_INSTRUCTIONS = """
You are a [FILL IN: role and institution] ...

Your capabilities:
- Events: [list what you can do with events]
- Venues: [list what you can do with venues]
- Notifications: [list what you can do with notifications]

Tool usage rules:
- [When to call which tool, e.g., always use get_events() before recommending events]
- [What to do before booking a venue]
- [What info to collect before calling WRITE tools]

Information gathering:
- [What to do when required info is missing]

Behavioral guidelines:
- [Tone and conciseness expectations]
- [How to respond after a successful action]
- [How to handle errors]
"""

print("✅ Agent instructions defined")
print(f"   Length: {len(AGENT_INSTRUCTIONS.split())} words")

# %% [markdown]
# <details>
# <summary><b>💡 Sample Solution</b></summary>
#
# ```python
# AGENT_INSTRUCTIONS = """
# You are a helpful campus management assistant at an engineering college.
# You help students, clubs, and organizers with events, venues, and campus-wide communications.
#
# Your capabilities:
# - Events: Browse all events (get_events), get event details (get_event_details),
# 		  register students (register_for_event), view participants (get_event_participants),
# 		  cancel registration (unregister_from_event)
# - Venues: List venues (get_venues), check availability (check_venue_availability),
# 		  book spaces for clubs (book_venue)
# - Notifications: Send announcements (send_event_notification),
# 				 review notification history (get_notification_history)
#
# Tool usage rules:
# - Always call get_events() to retrieve fresh data before recommending events;
#   never invent or assume event details.
# - Always call check_venue_availability() BEFORE booking a venue.
# - For WRITE operations (register, book, send notification), confirm all required
#   fields are provided before calling the tool. Ask politely if anything is missing.
#
# Information gathering:
# - If student_id, student_name, or event_id is missing for registration — ask the user.
# - If venue_id, date, or time_slot is missing for booking — ask the user.
# - If the user says "that event" or "this venue", clarify which one before proceeding.
#
# Behavioral guidelines:
# - Be friendly and concise (under 80 words unless the user asks for more detail).
# - Always echo back key details from tool results in your response
#   (event name, date, venue for registrations; venue name, time slot for bookings).
# - If a tool call fails, apologize briefly and suggest an alternative action.
# - Do not call tools speculatively — only call them when the user's request clearly requires it.
# - Use formatting (bold for names, emojis for clarity) to make responses scannable.
# """
# ```
# </details>

# %% [markdown]
# ---
# ## Part H: Assemble the Agent
#
# Now we wire everything together — the model client, instructions, and all 10 tools.

# %%
# Initialize the LLM client pointing to GitHub Models
chat_client = OpenAIChatClient(
    model="openai/gpt-4o-mini",
    api_key=GITHUB_PAT,
    base_url="https://models.github.ai/inference"
)

print("✅ Chat client initialized (gpt-4o-mini via GitHub Models)")

# %%
# Create the campus management agent with all 10 tools
campus_agent = Agent(
    client=chat_client,
    instructions=AGENT_INSTRUCTIONS,
    tools=[
        # Event tools
        get_events,
        get_event_details,
        register_for_event,
        get_event_participants,
        unregister_from_event,
        # Venue tools
        get_venues,
        check_venue_availability,
        book_venue,
        # Notification tools
        send_event_notification,
        get_notification_history,
    ]
)

print("✅ Campus Management Agent created!")
print(f"   Tools: 10 (5 event + 3 venue + 2 notification)")
print(f"   Model: gpt-4o-mini")

# %% [markdown]
# ---
# ## Part I: Test Your Agent — Individual Tool Calls
#
# Let's run targeted tests to verify each tool category is working correctly.
# We'll use `print_agent_response(response, show_details=True)` to see which tools were called.

# %%
# Test 1: Browse all events
print("=" * 60)
print("TEST 1: Browse All Events")
print("=" * 60)
response = await campus_agent.run("What events are happening on campus?")
print_agent_response(response, show_details=True)

# %%
# Test 2: Get event details
print("=" * 60)
print("TEST 2: Get Event Details")
print("=" * 60)
response = await campus_agent.run("Tell me more about the AI Workshop")
print_agent_response(response, show_details=True)

# %%
# Test 3: Register a student (WRITE test)
print("=" * 60)
print("TEST 3: Register a Student")
print("=" * 60)
response = await campus_agent.run(
    "I'm Priya with student ID S001. Please register me for the AI Workshop."
)
print_agent_response(response, show_details=True)

# %%
# Test 4: View participants after registration
print("=" * 60)
print("TEST 4: View Participants")
print("=" * 60)
response = await campus_agent.run("Who's registered for the AI Workshop?")
print_agent_response(response, show_details=True)

# %%
# Test 5: Check venue availability
print("=" * 60)
print("TEST 5: Check Venue Availability")
print("=" * 60)
response = await campus_agent.run(
    "Is Seminar Hall A available on 2024-04-15 from 10:00-12:00?"
)
print_agent_response(response, show_details=True)

# %%
# Test 6: Book a venue
print("=" * 60)
print("TEST 6: Book a Venue")
print("=" * 60)
response = await campus_agent.run(
    "Book Seminar Hall A for the AI Club on April 15th, 2024 from 10:00-12:00 "
    "for a machine learning workshop. We expect 60 attendees."
)
print_agent_response(response, show_details=True)

# %%
# Test 7: Send a notification
print("=" * 60)
print("TEST 7: Send a Notification")
print("=" * 60)
response = await campus_agent.run(
    "Send a reminder to all participants of the AI Workshop: "
    "'Reminder: The AI Workshop is tomorrow at 2 PM in Seminar Hall B. Don\'t forget to bring your laptop!'"
)
print_agent_response(response, show_details=True)

# %% [markdown]
# ---
# ## Part J: Multi-Turn Conversations
#
# Agents become truly powerful when they can maintain context across multiple turns.
# A **Thread** is what preserves conversation history between messages.
#
# ### Pre-Implemented Example: The Complete Student Journey
#
# Watch how the agent remembers context — Rahul's name and ID from Turn 1 are still used in Turn 4.

# %%
# Create a conversation session
example_session = campus_agent.create_session()
print("✅ New conversation session created\n")

# %%
# Turn 1: Student introduces themselves
response1 = await campus_agent.run(
    "Hi! I'm Rahul and my student ID is S002.",
    session=example_session
)
print("TURN 1 — Introduction:")
print_agent_response(response1)

# %%
# Turn 2: Browse events
response2 = await campus_agent.run(
    "What events can I join?",
    session=example_session
)
print("TURN 2 — Browse events:")
print_agent_response(response2)

# %%
# Turn 3: Ask about a specific event
response3 = await campus_agent.run(
    "Tell me more about TechFest 2024",
    session=example_session
)
print("TURN 3 — Event details:")
print_agent_response(response3)

# %%
# Turn 4: Register (agent uses Rahul's name and ID from Turn 1)
response4 = await campus_agent.run(
    "Register me for it.",   # Note: "it" refers to TechFest 2024 from context
    session=example_session
)
print("TURN 4 — Registration:")
print_agent_response(response4)
print()
print("💡 Notice: The agent remembered Rahul's name and ID from Turn 1,")
print("   and understood 'it' as TechFest 2024 from Turn 3!")

# %% [markdown]
# ### 📝 Design Your Own Multi-Turn Scenario (Your Turn!)
#
# Now it's your chance to design a realistic student/organizer journey.
# Your scenario should:
# - Have **at least 3 turns**
# - Demonstrate **context retention** (agent uses info from earlier turns)
# - Cover **at least 2 different tool categories** (events + venues, or events + notifications, etc.)
#
# Pick one of these starting points or invent your own:
#
# **Scenario A — The Venue Organizer**: "I'm the president of the Robotics Club. I need to find and book a venue for our demo day on April 10th, and then notify all AI Workshop participants."
#
# **Scenario B — The Busy Student**: "Show me all events → register for two of them back-to-back → then check if I can cancel one."
#
# **Scenario C — The Event Coordinator**: "Check which venues are free on a specific date → book one → send a campus-wide announcement about a new event."

# %%
# TODO: Design your own multi-turn conversation scenario.
#
# Instructions:
#   1. Create a new session: my_session = campus_agent.create_session()
#   2. Plan 3–5 turns that tell a coherent story
#   3. Make sure the agent needs to carry context from one turn to the next
#   4. Use print_agent_response(response, show_details=True) to inspect tool calls
#
# Template to get started:

my_session = campus_agent.create_session()
print("✅ Your custom conversation session created\n")

# Turn 1:
response_t1 = await campus_agent.run(
    "...",         # TODO: Replace with your opening message
    session=my_session
)
print("YOUR TURN 1:")
print_agent_response(response_t1, show_details=True)

# Turn 2:
response_t2 = await campus_agent.run(
    "...",         # TODO: Replace with your second message (reference something from Turn 1)
    session=my_session
)
print("YOUR TURN 2:")
print_agent_response(response_t2, show_details=True)

# Turn 3:
response_t3 = await campus_agent.run(
    "...",         # TODO: Replace with your third message
    session=my_session
)
print("YOUR TURN 3:")
print_agent_response(response_t3, show_details=True)

# Add more turns as needed:
# response_t4 = await campus_agent.run("...", session=my_session)
# ...

# %% [markdown]
# ---
# ## Part K: Interactive Chat Session
#
# You've built and tested every part of your agent. Now let's talk to it freely!
#
# Type your questions and requests in natural language. Try things like:
# - *"What events are happening this month?"*
# - *"I'm [your name], ID [your ID]. Register me for the hackathon."*
# - *"Check if Seminar Hall B is free on April 20th around 2 PM."*
# - *"Send a notification to TechFest participants that it starts at 10 AM sharp."*
# - *"Who's registered for the robotics demo?"*
#
# Type `quit` or `exit` to end the session.

# %%
async def interactive_chat():
    """Run an interactive multi-turn chat session with the campus management agent."""
    session = campus_agent.create_session()

    print("=" * 65)
    print("  🎓 CAMPUS MANAGEMENT AGENT — Interactive Session")
    print("=" * 65)
    print("  Type your message below. Type 'quit' or 'exit' to end.\n")

    while True:
        user_input = input("You: ").strip()

        if not user_input:
            continue
        if user_input.lower() in ["quit", "exit", "q"]:
            print("\nGoodbye! 👋")
            break

        response = await campus_agent.run(user_input, session=session)
        print(f"\nAgent: {response.text}\n")
        print("-" * 65)

# %%
# Start the interactive session!
await interactive_chat()

# %% [markdown]
# ---
# ## Part L: Edge Cases — How Does Your Agent Handle These?
#
# A robust agent handles unexpected inputs gracefully. Test these scenarios to evaluate yours:

# %%
# Edge case 1: Missing information — agent should ASK rather than guess
print("EDGE CASE 1: Missing Info")
print("=" * 60)
response = await campus_agent.run("I want to register for an event.")
print(f"Agent: {response.text}\n")
print("💡 Did the agent ask for the missing student_id, name, or event?")

# %%
# Edge case 2: Trying to book a venue that's full / over capacity
print("EDGE CASE 2: Over-Capacity Booking")
print("=" * 60)
response = await campus_agent.run(
    "Book the Computer Lab 1 for the AI Club on 2024-04-15 from 10:00-12:00 "
    "for a general meetup. We expect 200 people."  # Lab capacity is only 60
)
print(f"Agent: {response.text}\n")
print("💡 Did the agent relay the capacity error from the backend?")

# %%
# Edge case 3: Duplicate registration
print("EDGE CASE 3: Duplicate Registration")
print("=" * 60)
# Register Priya again (already registered in Test 3)
response = await campus_agent.run(
    "Register Priya (S001) for the AI Workshop again."
)
print(f"Agent: {response.text}\n")
print("💡 Did the agent handle the 'already registered' message gracefully?")

# %%
# Edge case 4: Multi-step task in a single message
print("EDGE CASE 4: Multi-Step Single Message")
print("=" * 60)
response = await campus_agent.run(
    "List all events, then tell me about the Spring Hackathon, "
    "and register me as Amit (S003) for it."
)
print_agent_response(response, show_details=True)
print("💡 Did the agent execute all three steps in sequence?")

# %% [markdown]
# ---
# ## 🎉 Lab 1 Complete!
#
# ### What You Built
#
# You've created a **fully-functional, multi-domain Campus Management Agent** with:
#
# | Capability | Tools |
# |---|---|
# | 📅 Event Management | `get_events`, `get_event_details`, `register_for_event`, `get_event_participants`, `unregister_from_event` |
# | 🏛️ Venue Management | `get_venues`, `check_venue_availability`, `book_venue` |
# | 📢 Notifications | `send_event_notification`, `get_notification_history` |
#
# ### Key Concepts Mastered
#
# 1. **Tool design** — clear docstrings, type-annotated parameters, formatted return strings
# 2. **Read vs. Write tools** — GET for discovery, POST for actions, DELETE for cancellations
# 3. **Auto-schema generation** — type hints drive the JSON schema the LLM reads
# 4. **Agent instructions** — system prompts define role, capabilities, and decision rules
# 5. **Thread-based conversations** — context is preserved across turns
# 6. **Edge case handling** — missing info, over-capacity, duplicates
# 7. **Multi-domain orchestration** — a single agent can handle multiple backend systems
#
# ### Thinking Further
#
# - **What would happen if two tools conflict?** (e.g., book a full venue)
# - **How would you add authentication?** (only organizers can send campus-wide notifications)
# - **What if the backend is slow?** (caching, retry logic, timeouts)
# - **How would you extend this to support multi-agent patterns?** (a planner agent + specialist agents for events/venues/notifications)
#
# ---
#
# *You now have the skills to build real AI agents. Go build something amazing! 🚀*
